# %%
# !pip install pandas pyarrow

# %%
import pandas as pd

# Het pad naar het Parquet-bestand
parquet_file_path_aed = r"C:\Users\mtver\OneDrive - KU Leuven\Studies\Master\Semester 2\Modern data analytics\Project\aed_locations.parquet.gzip"

# Gebruik pandas om het Parquet-bestand te lezen
df_aed = pd.read_parquet(parquet_file_path_aed)

# Bekijk de inhoud van het dataframe
print(df_aed.head(60))
# Out:
# C:\Users\mtver\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\mtver\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
#        id                              type  \
# 0    13.0                              None
# 1    70.0                              None
# 2    71.0                              None
# 3    72.0                              None
# 4    73.0                              None
# 5    74.0                              None
# 6    75.0                              None
# 7    76.0                              None
# 8    77.0                              None
# 9    78.0                              None
# ...

# %%
parquet_file_path_ambulance = r"C:\Users\mtver\OneDrive - KU Leuven\Studies\Master\Semester 2\Modern data analytics\Project\ambulance_locations.parquet.gzip"

# Gebruik pandas om het Parquet-bestand te lezen
df_ambulance = pd.read_parquet(parquet_file_path_ambulance)

# Bekijk de inhoud van het dataframe
print(df_ambulance.head(30))
# Out:
#                                       base  \
# 0              BA ANTW [Borgerhout] AMBUCE
# 1                 BA ANTW [Hoboken] AMBUCE
# 2   BA ANTW [Hof Ter Schelde] AC Antwerpen
# 3                 BA ANTW [Kaai 606] SIHWA
# 4    BA ANTW [Sint Elisabeth] AC Antwerpen
# 5                BA AREN Gemeente Arendonk
# 6                        BA BEER AD BEERSE
# 7                       BA BERL Rode Kruis
# 8                   BA ESSE Gemeente Essen
# 9                    BA HERS Hulshoutse AD
# 10                          BA KAPE AMBUCE
# 11                         BA KONT ACL ACK
# 12                    BA RAVE Vlaams Kruis
# 13                          BA WIJN AMBUCE
# 14                    BA ZAND Vlaams Kruis
# 15             BB BRUX Hôpital Militair KA
# 16                     BB FORE Croix Rouge
# 17                    BF HULP ACS La Hulpe
# 18                     BF OTTI Croix Rouge
# 19                     BG AMAY Croix Rouge
# 20                           BG AWAN PARAM
# ...

# %%
parquet_file_path_pit = r"C:\Users\mtver\OneDrive - KU Leuven\Studies\Master\Semester 2\Modern data analytics\Project\pit_locations.parquet.gzip"

# Gebruik pandas om het Parquet-bestand te lezen
df_pit = pd.read_parquet(parquet_file_path_pit)

# Bekijk de inhoud van het dataframe
print(df_pit.head(30))
# Out:
#                                                unit  \
# 0                  100001: PIT Rumst, AZ Rivierland
# 1                102001: PIT Deinze, St Vincentius
# 2                           102101: PIT Stuivenberg
# 3                     110001: PIT Lier, Heilig Hart
# 4                113001: PIT HEILIG HART ZIEKENHUIS
# 5                               200001: PIT LOKEREN
# 6                             210001: PIT ASSE, OLV
# 7          301001: PIT ST Jan (Associatie St Lucas)
# 8   301001: PIT St Lucas Brugge (associatie St Jan)
# 9                          303001: PIT Blankenberge
# 10                        404001: PIT Genk, St Jan
# 11                501001: PIT Leuven, Gasthuisberg
# 12                   520001: PIT Ixelles, Iris Sud
# 13                  523001: PIT St Pierre Bruxelles
# 14                           526001: PIT UZ BRUSSEL
# 15                                600001: PIT GILLY
# 16                                 601001: PIT MONS
# ...

# %%
parquet_file_path_mug = r"C:\Users\mtver\OneDrive - KU Leuven\Studies\Master\Semester 2\Modern data analytics\Project\mug_locations.parquet.gzip"

# Gebruik pandas om het Parquet-bestand te lezen
df_mug = pd.read_parquet(parquet_file_path_mug)

# Bekijk de inhoud van het dataframe
print(df_mug.head(30))
# Out:
#     hospital_id  mug_id  campus_id                            name_hospital  \
# 0             9  102000       6230        ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 1            99  102000       2020                        GZA- ZIEKENHUIZEN
# 2           682  102000       1210                                AZ MONICA
# 3             9  103000       2000        ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 4            99  103000       1290                        GZA- ZIEKENHUIZEN
# 5             9  104000       3360        ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 6           710  104000       3450                                 AZ KLINA
# 7           300  105000       4220        UNIVERSITAIR ZIEKENHUIS ANTWERPEN
# 8           308  106000       1250                             AZ HERENTALS
# 9            63  107000       1280                              AZ TURNHOUT
# 10          536  108000       2090                            AZ VOORKEMPEN
# ...

# %%
parquet_file_path_bxl = r"C:\Users\mtver\OneDrive - KU Leuven\Studies\Master\Semester 2\Modern data analytics\Project\interventions_bxl.parquet.gzip"

# alle kolommen weergeven
pd.set_option('display.max_columns', None)

# Gebruik pandas om het Parquet-bestand te lezen
df_bxl = pd.read_parquet(parquet_file_path_bxl)

# Bekijk de inhoud van het dataframe
print(df_bxl.head(10))
# Out:
#     mission_id                         service_name  postalcode_permanence  \
# 0  20222490011        FB PDS BRUX [PASI CitÈ] SIAMU                   1000
# 1  20222490011        FB PDS BRUX [PASI CitÈ] SIAMU                   1000
# 2  20222490012             HB UR BRUX CHU St Pierre                   1000
# 3  20222490015        FB PDS BRUX [PASI CitÈ] SIAMU                   1000
# 4  20222490019         FB PDS WOLL [PASI UCL] SIAMU                   1200
# 5  20222490019         FB PDS WOLL [PASI UCL] SIAMU                   1200
# 6  20222490019             HB UR BRUX Europe Michel                   1040
# 7  20222490020         FB PDS WOLL [PASI UCL] SIAMU                   1200
# 8  20222490021  FB PDS SCHA [PASI Paul Brien] SIAMU                   1030
# 9  20222490022          HB UR BRUX Europe Elisabeth                   1180
#
#                            cityname_permanence  \
# 0                            Brussel (Brussel)
# ...

# %%
parquet_file_path_bxl2 = r"C:\Users\mtver\OneDrive - KU Leuven\Studies\Master\Semester 2\Modern data analytics\Project\interventions_bxl2.parquet.gzip"

# Gebruik pandas om het Parquet-bestand te lezen
df_bxl2 = pd.read_parquet(parquet_file_path_bxl2)

# Bekijk de inhoud van het dataframe
print(df_bxl2.head(30))
# Out:
#      Mission ID                T0  \
# 0   20221520003  01JUN22:00:02:45
# 1   20221520005  01JUN22:00:04:58
# 2   20221520006  01JUN22:00:07:43
# 3   20221520006  01JUN22:00:07:43
# 4   20221520007  01JUN22:00:09:18
# 5   20221520008  01JUN22:00:17:29
# 6   20221520009  01JUN22:00:25:45
# 7   20221520011  01JUN22:00:29:27
# 8   20221520012  01JUN22:00:42:00
# 9   20221520013  01JUN22:00:43:04
# 10  20221520014  01JUN22:00:44:36
# 11  20221520014  01JUN22:00:44:36
# 12  20221520014  01JUN22:00:44:36
# 13  20221520015  01JUN22:00:51:17
# 14  20221520017  01JUN22:01:01:47
# 15  20221520018  01JUN22:01:04:35
# 16  20221520019  01JUN22:01:08:54
# 17  20221520020  01JUN22:01:14:04
# 18  20221520020  01JUN22:01:14:04
# 19  20221520021  01JUN22:01:19:37
# 20  20221520022  01JUN22:01:20:30
# 21  20221520023  01JUN22:01:31:02
# 22  20221520025  01JUN22:01:38:44
# 23  20221520027  01JUN22:01:44:10
# 24  20221520028  01JUN22:02:18:47
# 25  20221520029  01JUN22:02:21:21
# ...

# %%
parquet_file_path_int1 = r"C:\Users\mtver\OneDrive - KU Leuven\Studies\Master\Semester 2\Modern data analytics\Project\interventions1.parquet.gzip"

# Gebruik pandas om het Parquet-bestand te lezen
df_int1 = pd.read_parquet(parquet_file_path_int1)

# Bekijk de inhoud van het dataframe
print(df_int1.head(30))
# Out:
#      Mission ID                  Service Name  PostalCode permanence  \
# 0   10221520001      HA UR MECH AZ St Maarten                 2800.0
# 1   10221520002                BA KAPE AMBUCE                 2950.0
# 2   10221520002        HA UR ANTW Stuivenberg                 2060.0
# 3   10221520004   BA ANTW [Borgerhout] AMBUCE                 2140.0
# 4   10221520005                BA WIJN AMBUCE                 2110.0
# 5   10221520006         FA HVP BEER Taxandria                 2340.0
# 6   10221520007         BA KALM GEM Kalmthout                 2920.0
# 7   10221520008      HA UR MECH AZ St Maarten                 2800.0
# 8   10221520009  FA HVP ANTW [Zuid] Antwerpen                 2018.0
# 9   10221520009      HA UR ANTW St Vincentius                 2018.0
# 10  10221520010         HA UR ANTW Middelheim                 2020.0
# 11  10221520011      HA UR ANTW St Vincentius                 2018.0
# 12  10221520011        HA UR ANTW Stuivenberg                 2060.0
# ...

# %%
parquet_file_path_int2 = r"C:\Users\mtver\OneDrive - KU Leuven\Studies\Master\Semester 2\Modern data analytics\Project\interventions2.parquet.gzip"

# Gebruik pandas om het Parquet-bestand te lezen
df_int2 = pd.read_parquet(parquet_file_path_int2)

# Bekijk de inhoud van het dataframe
print(df_int2.head(30))
# Out:
#      Mission ID                                  Service Name  \
# 0   50221920087                  FH PDS COMI Wallonie Picarde
# 1   50221920088                  FH PDS TOUR Wallonie Picarde
# 2   50221920089                    FH PDS LOUV Hainaut Centre
# 3   50221920090             FW HVP HEUV [Nieuwkerke] Westhoek
# 4   50221920092                           BH SGHI Croix Rouge
# 5   50221920092  HH UR BOUS CH Epicura (H√¥pital Grand Hornu)
# 6   50221920093                                HH UR MOUS CHM
# 7   50221920093                  FH PDS MOUS Wallonie Picarde
# 8   50221920094                    FH PDS LOUV Hainaut Centre
# 9   50221920095               FH PDS CHAR [Jumet] Hainaut Est
# 10  50221920096                                 BH CHAR R-MED
# 11  50221920103                  FH PDS TOUR Wallonie Picarde
# 12  50221920106          FH PDS MONS [Cuesmes] Hainaut Centre
# 13  50221920107                  FH PDS ATH_ Wallonie Picarde
# ...

# %%
parquet_file_path_int3 = r"C:\Users\mtver\OneDrive - KU Leuven\Studies\Master\Semester 2\Modern data analytics\Project\interventions3.parquet.gzip"

# Gebruik pandas om het Parquet-bestand te lezen
df_int3 = pd.read_parquet(parquet_file_path_int3)

# Bekijk de inhoud van het dataframe
print(df_int3.head(30))
# Out:
#      Mission ID                                  Service Name  \
# 0   60230050009                           BG LIEG Croix Rouge
# 1   60230050010            FG PDS PEPI Vesdre Ho√´gne Plateau
# 2   60230050012                              BG LIEG Courtois
# 3   60230050013                       FG PDS ANS_ Li√®ge IILE
# 4   60230050014                       FG PDS FLEM Li√®ge IILE
# 5   60230050017                                FG PDS EUPE DG
# 6   60230050018             FG PDS LIEG [Caserne] Li√®ge IILE
# 7   60230050019                            FG PDS HUY_ HEMECO
# 8   60230050020                                 BG AWAN PARAM
# 9   60230050022                           BG LIEG Croix Rouge
# 10  60230050023                           BG AMAY Croix Rouge
# 11  60230050023                                HG UR HUY_ CHR
# 12  60230050024                       FG PDS ANS_ Li√®ge IILE
# 13  60230050026  FG PDS HERV [Battice] Vesdre Ho√´gne Plateau
# ...

# %%
parquet_file_path_cad9 = r"C:\Users\mtver\OneDrive - KU Leuven\Studies\Master\Semester 2\Modern data analytics\Project\cad9.parquet.gzip"

# Gebruik pandas om het Parquet-bestand te lezen
df_cad9 = pd.read_parquet(parquet_file_path_cad9)

# Bekijk de inhoud van het dataframe
print(df_cad9.head(30))
# Out:
#    province   Mission ID                   Service Name  Latitude permanence  \
# 0       VBR  21221520003               MV HVP VILV West            50.925277
# 1       VBR  21221520004               MV HVP HALL West            50.743200
# 2       VBR  21221520007               MV HVP VILV West            50.925277
# 3       VBR  21221520007     HV UR VILV AZ Jan Portaels            50.926869
# 4       VBR  21221520008    BB BRUX Hôpital Militair KA            50.905331
# 5       VBR  21221520012               MV HVP VILV West            50.925277
# 6       VBR  21221520013           BV LEUV 112 Hageland            50.869703
# 7       VBR  21221520014                  HB UR BRUX UZ            50.885497
# 8       VBR  21221520014               MV HVP ASSE West            50.907977
# 9       VBR  21221520015     HV UR LEUV UZ Gasthuisberg            50.877462
# 10      VBR  21221520015      HV UR LEUV RZ Heilig Hart            50.872214
# ...
